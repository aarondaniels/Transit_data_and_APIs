# %%
mbtaURL = "https://api-v3.mbta.com/vehicles?filter[route]=1&include=trip"

import urllib.request, json
with urllib.request.urlopen(mbtaURL) as url:
    data = json.loads(url.read().decode())
   
    with open('data.json', 'w') as outfile:
        json.dump(data, outfile)
   
    with open('data.txt', 'w') as outfile:
        json.dump(json.dumps(data, indent=4, sort_keys=True), outfile)
       
    print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "attributes": {
#                 "bearing": 340,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 15,
#                 "direction_id": 0,
#                 "label": "1907",
#                 "latitude": 42.35753455,
#                 "longitude": -71.09271397,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-09-05T18:18:57-04:00"
#             },
#             "id": "y1907",
#             "links": {
#                 "self": "/vehicles/y1907"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "97",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53291849",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 16,
#                 "direction_id": 1,
#                 "label": "1840",
#                 "latitude": 42.340773779,
#                 "longitude": -71.082115009,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-09-05T18:18:53-04:00"
#             },
#             "id": "y1840",
#             "links": {
#                 "self": "/vehicles/y1840"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "84",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53291912",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 111,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 11,
#                 "direction_id": 1,
#                 "label": "1789",
#                 "latitude": 42.35747791,
#                 "longitude": -71.09296147,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-09-05T18:18:54-04:00"
#             },
#             "id": "y1789",
#             "links": {
#                 "self": "/vehicles/y1789"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "77",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53291933",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 46,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 2,
#                 "direction_id": 1,
#                 "label": "1787",
#                 "latitude": 42.32979285,
#                 "longitude": -71.08320305,
#                 "occupancy_status": null,
#                 "speed": null,
#                 "updated_at": "2022-09-05T18:18:59-04:00"
#             },
#             "id": "y1787",
#             "links": {
#                 "self": "/vehicles/y1787"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "1",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53291847",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 90,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 1,
#                 "direction_id": 1,
#                 "label": "1784",
#                 "latitude": 42.32977,
#                 "longitude": -71.08379,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-09-05T18:18:14-04:00"
#             },
#             "id": "y1784",
#             "links": {
#                 "self": "/vehicles/y1784"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "64",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53291869",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 18,
#                 "direction_id": 0,
#                 "label": "1771",
#                 "latitude": 42.36382785,
#                 "longitude": -71.101038439,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-09-05T18:18:57-04:00"
#             },
#             "id": "y1771",
#             "links": {
#                 "self": "/vehicles/y1771"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "102",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53292942",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 268,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 1,
#                 "direction_id": 0,
#                 "label": "1751",
#                 "latitude": 42.3730689,
#                 "longitude": -71.11775006,
#                 "occupancy_status": null,
#                 "speed": null,
#                 "updated_at": "2022-09-05T18:18:57-04:00"
#             },
#             "id": "y1751",
#             "links": {
#                 "self": "/vehicles/y1751"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "110",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53291848",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         }
#     ],
#     "included": [
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-6",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53291847",
#             "links": {
#                 "self": "/trips/53291847"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "LaborDay-ThanksgivingDay",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010116",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-5",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53291848",
#             "links": {
#                 "self": "/trips/53291848"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "LaborDay-ThanksgivingDay",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010111",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-4",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53291849",
#             "links": {
#                 "self": "/trips/53291849"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "LaborDay-ThanksgivingDay",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010111",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-7",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53291869",
#             "links": {
#                 "self": "/trips/53291869"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "LaborDay-ThanksgivingDay",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010116",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-8",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53291912",
#             "links": {
#                 "self": "/trips/53291912"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "LaborDay-ThanksgivingDay",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010116",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-1",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53291933",
#             "links": {
#                 "self": "/trips/53291933"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "LaborDay-ThanksgivingDay",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010116",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-3",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53292942",
#             "links": {
#                 "self": "/trips/53292942"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "LaborDay-ThanksgivingDay",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010111",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         }
#     ],
#     "jsonapi": {
#         "version": "1.0"
#     }
# }
